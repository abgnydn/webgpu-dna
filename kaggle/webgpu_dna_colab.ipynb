# %% [markdown]
# # webgpu-dna on Colab/Kaggle — try the real GPU, measure honestly
#
# 1. **Best-effort** to reach the real GPU for WebGPU (installs the NVIDIA Vulkan
#    producer for the running driver, registers an ICD).
# 2. **Measures** which adapter `wgpu-py` actually gets — real GPU vs software
#    (`llvmpipe`). Datacenter Tesla driver is CUDA-only, so this is the honest test.
# 3. **Validates** the real shipped WGSL (primary/secondary/chemistry, assembled
#    exactly like `src/shaders/loader.ts`) on `wgpu-native` either way — a free
#    cross-implementation check even if the GPU stays unreachable.
#
# **Runtime → Change runtime type → GPU (T4)**, then **Run all**.

# %%
# Clone the branch with the smoke script, then run it.
# !git clone --depth 1 -b claude/nice-gauss-ssp1c4 https://github.com/abgnydn/webgpu-dna 2>/dev/null || git -C webgpu-dna pull -q
# !python webgpu-dna/kaggle/colab_webgpu_smoke.py
